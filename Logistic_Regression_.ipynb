# %% [markdown]
# <a href="https://colab.research.google.com/github/PRANAV40/Machine_Learning/blob/main/Logistic_Regression_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Φ(z) = 1/1 + e-z
#p = 1/ 1 + e-(b0+b1x) 
#Logistic Regression = Sigmoid(Linear Regression)

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7c017c31-4ab4-45a6-b933-0b77c41f7bab" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7c017c31-4ab4-45a6-b933-0b77c41f7bab">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np
path = 'heart.csv'
df = pd.read_csv(path)
df.head()
# Out:
#    age  gender  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0   63       1   3       145   233    1        0      150      0      2.3
# 1   37       1   2       130   250    0        1      187      0      3.5
# 2   41       0   1       130   204    0        0      172      0      1.4
# 3   56       1   1       120   236    0        1      178      0      0.8
# 4   57       0   0       120   354    0        1      163      1      0.6
#
#    slope  ca  thal  target
# 0      0   0     1       1
# 1      0   0     2       1
# 2      2   0     2       1
# 3      2   0     2       1
# 4      2   0     2       1

# %%
X = df.drop("target",1)
Y = df["target"]
# Out:
# <ipython-input-3-db297d0c0a06>:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   X = df.drop("target",1)

# %%
corr=df.corr()
cor_target = abs(corr["target"])
relevant_features = cor_target[cor_target>=0.35]
relevant_features
# Out:
# cp         0.433798
# thalach    0.421741
# exang      0.436757
# oldpeak    0.430696
# ca         0.391724
# target     1.000000
# Name: target, dtype: float64

# %%
X_new = df[['cp','thalach','exang','oldpeak','slope','ca','thal']]
X_new
# Out:
#      cp  thalach  exang  oldpeak  slope  ca  thal
# 0     3      150      0      2.3      0   0     1
# 1     2      187      0      3.5      0   0     2
# 2     1      172      0      1.4      2   0     2
# 3     1      178      0      0.8      2   0     2
# 4     0      163      1      0.6      2   0     2
# ..   ..      ...    ...      ...    ...  ..   ...
# 298   0      123      1      0.2      1   0     3
# 299   3      132      0      1.2      1   0     3
# 300   0      141      0      3.4      1   2     3
# 301   0      115      1      1.2      1   1     3
# 302   1      174      0      0.0      1   1     2
#
# [303 rows x 7 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split( X_new, Y, test_size=0.3)
print ('Train set:', X_train.shape, y_train.shape)
print ('Test set:', X_test.shape, y_test.shape)
# Out:
# Train set: (212, 7) (212,)
# Test set: (91, 7) (91,)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
k = 3
neigh = KNeighborsClassifier(n_neighbors = k).fit(X_train,y_train)
neigh
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
from sklearn import metrics
yhat = neigh.predict(X_test)

# %%
print("Train set Accuracy: ", metrics.accuracy_score(y_train, neigh.predict(X_train)))
print("Test set Accuracy: ", metrics.accuracy_score(y_test, yhat))
# Out:
# Train set Accuracy:  0.8773584905660378
# Test set Accuracy:  0.6813186813186813

# %%
from sklearn.linear_model import LogisticRegression

# %%
LR = LogisticRegression().fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
